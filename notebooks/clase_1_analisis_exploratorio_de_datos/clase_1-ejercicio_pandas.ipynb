# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_excel('/lustre/geocean/WORK/users/alonsoap/personal/dodencia/AnaliticaDeDatos/datos/clases/clase_1_analisis_exploratorio_de_datos/ENB2012_data.xlsx')

# %%
data.columns = [
    "relative_compactness",
    "surface_area",
    "wall_area",
    "roof_area",
    "overall_height",
    "orientation",
    "glazing_area",
    "glazing_distribution",
    "heating_load",
    "cooling_load"
]

# %% [markdown]
# #### 1. Conociendo los datos
# ¿Cuántas observaciones contiene el dataset? ¿Y cuántas variables?
# ¿Qué tipo de datos contiene cada variable?
# Muestra las primeras 10 observaciones.
# ¿Existen valores ausentes?
# ¿Cuál es la superficie mínima y máxima de los edificios?
# ¿Cuál es la altura mínima y máxima?

# %% [markdown]
# #### 2. Estadística descriptiva
#
# Para surface_area, wall_area, roof_area, overall_height, glazing_area, heating_load y cooling_load:
#
# Calcula la media, mediana y desviación estándar.
# ¿Cuál es el edificio con mayor demanda de calefacción?
# ¿Cuál es el edificio con menor demanda de refrigeración?
# Calcula los percentiles 25, 50 y 75 de heating_load.
# ¿Qué porcentaje de edificios tiene una demanda de calefacción superior a la media?

# %% [markdown]
# #### 3. Selección y filtrado
# Selecciona únicamente las columnas surface_area, overall_height, heating_load y cooling_load.
# Selecciona los edificios cuya superficie sea superior a 700 m².
# Selecciona los edificios que tengan:
# una superficie superior a 700 m² y
# una demanda de calefacción superior a 30.
# ¿Cuántos edificios cumplen estas condiciones?

# %% [markdown]
# #### 4. Variables categóricas
# ¿Qué valores diferentes aparecen en orientation?
# ¿Cuántos edificios hay para cada orientación?
# ¿Qué valores diferentes aparecen en glazing_distribution?
# ¿Cuántos edificios pertenecen a cada categoría?

# %%
#### pista
data['orientation'].unique()
# Out:
# array([2, 3, 4, 5])

# %% [markdown]
# #### 5. Comparaciones sencillas
# ¿Cuál es la demanda media de calefacción para cada orientación?
# ¿Cuál es la demanda media de refrigeración para cada categoría de glazing_distribution?
